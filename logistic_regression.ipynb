# %% [markdown]
# <a href="https://colab.research.google.com/github/monishaeswar/AI-Internship/blob/main/logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
X = np.array([[1], [2], [3], [4], [5], [6]])
y = np.array([0, 0, 0, 1, 1, 1])
model = LogisticRegression()
model.fit(X, y)
new_data = np.array([[4.5]])
prediction = model.predict(new_data)
probability = model.predict_proba(new_data)
print("Prediction (0=Fail, 1=Pass):", prediction[0])
print("Probability:", probability)
# Out:
# Prediction (0=Fail, 1=Pass): 1
# Probability: [[0.24585834 0.75414166]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
X = np.array([[1], [2], [3], [4], [5], [6]])
y = np.array([0, 0, 0, 1, 1, 1])
model = LogisticRegression()
model.fit(X, y)
new_data = np.array([[4.5]])
X_test=np.linspace(1,10,100).reshape(-1,1)
y_prob=model.predict_proba(X_test)[:,1]
plt.plot(X_test,y_prob,color='red',label='Sigmoid Curve')
prediction = model.predict(new_data)
print("Prediction (0=Fail, 1=Pass):", prediction[0])
plt.scatter(X, y, color='blue', label='Training Data')
plt.scatter(new_data, prediction, color='red', s=80, label='New Prediction')
plt.xlabel("Study Hours")
plt.ylabel("Pass (1) / Fail (0)")
plt.title("Logistic Regression")
plt.xticks(np.arange(1,11,1))
plt.yticks([0, 1], ["Fail", "Pass"])
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Prediction (0=Fail, 1=Pass): 1

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression

X = np.array([[1], [2], [3], [4], [5], [6]])
y = np.array([0, 0, 0, 1, 1, 1])

model = LogisticRegression()
model.fit(X, y)

new_data = np.array([[4.5]])
prediction = model.predict(new_data)
prob = model.predict_proba(new_data)

print(f"Prediction: {prediction[0]}")
print(f"Probabilities: {prob}")
# Out:
# Prediction: 1
# Probabilities: [[0.24585834 0.75414166]]
