# %% [markdown]
# <a href="https://colab.research.google.com/github/monishaeswar/AI-Internship/blob/main/Missing_Values_Duplicate_Values.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/employee.csv")

# %%
print(df)
# Out:
#     EmployeeID     Name   Age Department   Salary  Experience
# 0          101     Arun  25.0         IT  30000.0         2.0
# 1          102    Priya   NaN         HR  40000.0         3.0
# 2          103     Ravi  28.0    Finance      NaN         4.0
# 3          104    Divya  26.0         IT  35000.0         NaN
# 4          105  Karthik  30.0      Sales  45000.0         5.0
# 5          106    Meena  29.0         HR  42000.0         4.0
# 6          101     Arun  25.0         IT  30000.0         2.0
# 7          107   Suresh   NaN    Finance  38000.0         3.0
# 8          108    Latha  27.0        NaN  36000.0         2.0
# 9          109    Vijay  31.0      Sales  47000.0         6.0
# 10         110   Anitha  24.0         HR      NaN         1.0
# 11         111    Kiran  29.0         IT  41000.0         4.0
# 12         112    Priya  26.0         HR  40000.0         3.0

# %%
print(df.isnull())
# Out:
#     EmployeeID   Name    Age  Department  Salary  Experience
# 0        False  False  False       False   False       False
# 1        False  False   True       False   False       False
# 2        False  False  False       False    True       False
# 3        False  False  False       False   False        True
# 4        False  False  False       False   False       False
# 5        False  False  False       False   False       False
# 6        False  False  False       False   False       False
# 7        False  False   True       False   False       False
# 8        False  False  False        True   False       False
# 9        False  False  False       False   False       False
# 10       False  False  False       False    True       False
# 11       False  False  False       False   False       False
# 12       False  False  False       False   False       False

# %%
print(df.isnull().sum())
# Out:
# EmployeeID    0
# Name          0
# Age           2
# Department    1
# Salary        2
# Experience    1
# dtype: int64

# %%
df = df.dropna()

# %%
df["Age"] = df["Age"].fillna(df["Age"].mean())

# %%
df["Age"] = df["Age"].fillna(df["Age"].median())

# %%
df["Age"] = df["Age"].fillna(df["Age"].mode()[0])

# %%
df["Salary"] = df["Salary"].fillna(0)

# %%
print(df.duplicated())
# Out:
# 0     False
# 4     False
# 5     False
# 6      True
# 9     False
# 11    False
# 12    False
# dtype: bool

# %%
print(df.duplicated().sum())
# Out:
# 1

# %%
df = df.drop_duplicates()

# %%
print("\nCleaned Dataset")
print(df)
# Out:
# Cleaned Dataset
#     EmployeeID     Name   Age Department   Salary  Experience
# 0          101     Arun  25.0         IT  30000.0         2.0
# 4          105  Karthik  30.0      Sales  45000.0         5.0
# 5          106    Meena  29.0         HR  42000.0         4.0
# 9          109    Vijay  31.0      Sales  47000.0         6.0
# 11         111    Kiran  29.0         IT  41000.0         4.0
# 12         112    Priya  26.0         HR  40000.0         3.0

# %%
df.to_csv("cleaned_data.csv", index=False)
