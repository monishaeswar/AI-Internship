# %% [markdown]
# <a href="https://colab.research.google.com/github/monishaeswar/AI-Internship/blob/main/DecisionTreeClassifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report

# %%
df = pd.read_csv("Pass-Fail Data.csv")

# %%
X = df.drop(["student_id", "pass"], axis=1)
y = df["pass"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
model = DecisionTreeClassifier(random_state=42)

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        12
#            1       1.00      1.00      1.00        18
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
new_student = [[85, 90, 75, 8]]
prediction = model.predict(new_student)

if prediction[0] == 1:
    print("Prediction: PASS")
else:
    print("Prediction: FAIL")
# Out:
# Prediction: PASS
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
plt.figure(figsize=(12, 8))
plot_tree(
    model,
    feature_names=X.columns,
    class_names=["Fail", "Pass"],
    filled=True
)
# Out:
# [Text(0.5, 0.75, 'attendance_pct <= 66.5\ngini = 0.48\nsamples = 70\nvalue = [28, 42]\nclass = Pass'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 28\nvalue = [28, 0]\nclass = Fail'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 42\nvalue = [0, 42]\nclass = Pass'),
#  Text(0.625, 0.5, '  False')]

# %%
plt.figure(figsize=(12,8))

plot_tree(
    model,
    feature_names=X.columns,
    class_names=["Fail", "Pass"],
    filled=True,
    rounded=True,
    fontsize=10
)

plt.title("Decision Tree - Student Pass/Fail Prediction")
plt.show()

# %%
plt.figure(figsize=(5,4))
df["pass"].value_counts().plot(kind="bar")
plt.title("Pass vs Fail Students")
plt.xlabel("Pass (0=Fail, 1=Pass)")
plt.ylabel("Number of Students")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.scatter(df["study_hours_per_week"], df["midterm_score"], c=df["pass"])
plt.xlabel("Study Hours per Week")
plt.ylabel("Midterm Score")
plt.title("Study Hours vs Midterm Score")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(df["attendance_pct"], bins=10)
plt.title("Attendance Distribution")
plt.xlabel("Attendance %")
plt.ylabel("Frequency")
plt.show()
